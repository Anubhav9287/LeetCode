# %% [markdown]
# ![image.png](attachment:image.png)
# Given a string containing digits from 2-9 inclusive, return all possible letter combinations that the number could represent. Return the answer in any order.
# <br>
# A mapping of digits to letters (just like on the telephone buttons) is given below. Note that 1 does not map to any letters.<br>
# ![image-2.png](attachment:image-2.png)

# %%
class Solution:
    def backtrack(self,digits,indx,local_res):
        if indx >= len(digits):
            self.res.append("".join(local_res))
            return
        else:
            for char in self.digit_to_letter[digits[indx]]:
                local_res.append(char)
                self.backtrack(digits,indx+1,local_res)
                local_res.pop()

    def letterCombinations(self,digits):
        self.digit_to_letter = {
            '2':["a","b","c"],
            '3':["d","e","f"],
            '4':["g","h","i"],
            '5':["j","k","l"],
            '6':["m","n","o"],
            '7':["p","q","r","s"],
            '8':["t","u","v"],
            '9':["w","x","y","z"],
        }

        if len(digits) < 1:
            return []
        if len(digits) == 1:
            return self.digit_to_letter[digits]

        self.res = []

        self.backtrack(digits,0,[])

        return self.res

# %%
digits = "23"
a = Solution()
a.letterCombinations(digits)
# Out:
# ['ad', 'ae', 'af', 'bd', 'be', 'bf', 'cd', 'ce', 'cf']
