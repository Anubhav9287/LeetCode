# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Node:
    def __init__(self,key=0):
        self.val = key
        self.left = None
        self.right = None
#create Nodes:
a = Node(3)
b1 = Node(9)
b2 = Node(20)
c1 = Node(15)
c2 = Node(7)
#Node Connection:
a.left = b1
a.right = b2
b2.left = c1
b2.right = c2
#temp
q = Node()

# %%
def treeLevelOrderTraversal(root):
    output = []
    queue = []
    queue.append(root)
    while queue:
        level = []
        for i in range(len(queue)):
            curr = queue.pop(0)
            if curr:
                level.append(curr.val)
                if curr.left:
                    queue.append(curr.left)
                if curr.right:
                    queue.append(curr.right)
        if level:
            output.append(level)
        result = []
    return output

# %%
treeLevelOrderTraversal(a)
# Out:
# [[3], [9, 20], [15, 7]]
