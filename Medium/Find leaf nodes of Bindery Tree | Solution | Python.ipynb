# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Node:
    def __init__(self,key):
        self.val = key
        self.left = None
        self.right = None
a = Node(1)
b = Node(2)
a.left = b
a.right = Node(3)
b.left = Node(4)
b.right = Node(5)

# %%
def printF(root):
    if not root:
        return
    printF(root.left)
    print(root.val)
    printF(root.right)
printF(a)
# Out:
# 4
# 2
# 5
# 1
# 3

# %%
def onlyLeafNode(root):
    
def leafNode(root):
    res = []
    while root:
        res.append(onlyLeafNode(root))
        if not root:
            root = root.left
